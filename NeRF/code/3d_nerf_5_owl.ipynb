# %%
# !nvidia-smi
# Out:
# Sat Feb 26 07:17:21 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/nerf_project
# Out:
# /content/drive/MyDrive/nerf_project

# %%
# !git clone https://github.com/jason2133/vid2img.git

# %%
# %cd vid2img
# Out:
# /content/drive/MyDrive/nerf_project/vid2img

# %%
import cv2

video_file = '/content/drive/MyDrive/nerf_project/input_data/owl.mp4'

cap = cv2.VideoCapture(video_file)
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(length)
# Out:
# 2038

# %%
input_path = '/content/drive/MyDrive/nerf_project/input_data/image5_owl'

# %%
# !python vid2img.py {video_file} -o {input_path} -i 20 -e png

# %%
# %cd /content/drive/MyDrive/nerf_project
# Out:
# /content/drive/MyDrive/nerf_project

# %%
# !git clone https://github.com/jason2133/u2net.git

# %% [markdown]
# - Download u2net.pth from https://drive.google.com/file/d/1ao1ovG1Qtx4b7EoskHXmi2E9rp5CHLcZ/view?usp=sharing
#
# - Put u2net.pth to u2net/U-2-Net/saved_models/u2net

# %%
# %cd u2net
# Out:
# /content/drive/MyDrive/nerf_project/u2net

# %%
# 이미지들이 있는 폴더경로를 주면 이미지의 이름을 바꾸줌 ex) 0.png
# !python rename.py --image_path {input_path}

# %%
# %cd U-2-Net
# Out:
# /content/drive/MyDrive/nerf_project/u2net/U-2-Net

# %%
# 이미지 경로를 주면 이미지 경로_mask 폴더를 만든 후, 그 폴더에 mask된 이미지를 저장.
# !python u2net_test.py --image_path {input_path}
# Out:
# ['/content/drive/MyDrive/nerf_project/input_data/image5_owl/0.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/1.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/2.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/3.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/4.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/5.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/6.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/7.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/8.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/9.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/10.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/11.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/12.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_owl/13.jpg', '/content/drive/MyDrive/nerf_project/input_data/image5_
# ...

# %%
# %cd /content/drive/MyDrive/nerf_project/u2net
# Out:
# /content/drive/MyDrive/nerf_project/u2net

# %%
# 이미지 경로를 주면 이미지 경로_rm_bg 폴더를 만든 후, 그 폴더에 백그라운드 제거된 이미지를 저장.
# !python mask.py --image_path {input_path}
# Out:
# 102
# output_dir: /content/drive/MyDrive/nerf_project/input_data/image5_owl_rm_bg
# Masking image 0 completed.
#
# Masking image 1 completed.
#
# Masking image 2 completed.
#
# Masking image 3 completed.
#
# Masking image 4 completed.
#
# Masking image 5 completed.
#
# Masking image 6 completed.
#
# Masking image 7 completed.
#
# Masking image 8 completed.
#
# Masking image 9 completed.
#
# Masking image 10 completed.
#
# Masking image 11 completed.
#
# Masking image 12 completed.
#
# Masking image 13 completed.
#
# Masking image 14 completed.
#
# Masking image 15 completed.
#
# Masking image 16 completed.
#
# Masking image 17 completed.
#
# Masking image 18 completed.
#
# Masking image 19 completed.
#
# Masking image 20 completed.
#
# Masking image 21 completed.
#
# Masking image 22 completed.
#
# Masking image 23 completed.
#
# Masking image 24 completed.
#
# Masking image 25 completed.
#
# Masking image 26 completed.
#
# Masking image 27 completed.
#
# Masking image 28 completed.
# ...

# %% [markdown]
# ### 비디오를 세로로 촬영하는 바람에, 시계방향으로 90도 회전해야 하는 경우

# %%
import cv2
import numpy as np
import os
image_rotate_path = '/content/drive/MyDrive/nerf_project/input_data/image5_owl_rm_bg'

image_rotate_output_path = os.path.join(image_rotate_path + '_rotate')
if not os.path.exists(image_rotate_output_path):
    os.makedirs(image_rotate_output_path, exist_ok=True)
    print(f"image_rotate_output_path_dir: {image_rotate_output_path}")
# Out:
# image_rotate_output_path_dir: /content/drive/MyDrive/nerf_project/input_data/image5_owl_rm_bg_rotate

# %%
def get_files_count(folder_path):
  fileExt = r".png"
  jpg_list = [_ for _ in os.listdir(folder_path) if _.endswith(fileExt)]
  return len(jpg_list)

# %%
image_num = get_files_count(image_rotate_path)
print(image_num)
# Out:
# 102

# %%
# Save Results
for i in range(image_num):
  img1 = cv2.imread(os.path.join(image_rotate_path, str(i) + '.png'))
  img2 = cv2.rotate(img1, cv2.ROTATE_90_CLOCKWISE)
  output_path = image_rotate_output_path
  output_dir = os.path.join(output_path, str(i) + '.png')
  cv2.imwrite(output_dir, img2)
  print(f"Rotating image 90도 {i} completed")
# Out:
# Rotating image 90도 0 completed
# Rotating image 90도 1 completed
# Rotating image 90도 2 completed
# Rotating image 90도 3 completed
# Rotating image 90도 4 completed
# Rotating image 90도 5 completed
# Rotating image 90도 6 completed
# Rotating image 90도 7 completed
# Rotating image 90도 8 completed
# Rotating image 90도 9 completed
# Rotating image 90도 10 completed
# Rotating image 90도 11 completed
# Rotating image 90도 12 completed
# Rotating image 90도 13 completed
# Rotating image 90도 14 completed
# Rotating image 90도 15 completed
# Rotating image 90도 16 completed
# Rotating image 90도 17 completed
# Rotating image 90도 18 completed
# Rotating image 90도 19 completed
# Rotating image 90도 20 completed
# Rotating image 90도 21 completed
# Rotating image 90도 22 completed
# Rotating image 90도 23 completed
# Rotating image 90도 24 completed
# Rotating image 90도 25 completed
# Rotating image 90도 26 completed
# Rotating image 90도 27 completed
# Rotating image 90도 28 completed
# ...

# %% [markdown]
# ## Plenoxels 불러오기

# %%
# %cd /content/drive/MyDrive/nerf_project
# Out:
# /content/drive/MyDrive/nerf_project

# %%
# !git clone https://github.com/sxyu/svox2.git
# Out:
# Cloning into 'svox2'...
# remote: Enumerating objects: 1509, done.
# remote: Counting objects: 100% (1509/1509), done.
# remote: Compressing objects: 100% (834/834), done.
# remote: Total 1509 (delta 1125), reused 1039 (delta 660), pack-reused 0
# Receiving objects: 100% (1509/1509), 4.63 MiB | 10.23 MiB/s, done.
# Resolving deltas: 100% (1125/1125), done.

# %% [markdown]
# ## COLMAP

# %%
# !sudo apt-get install \
    git \
    cmake \
    build-essential \
    libboost-program-options-dev \
    libboost-filesystem-dev \
    libboost-graph-dev \
    libboost-system-dev \
    libboost-test-dev \
    libeigen3-dev \
    libsuitesparse-dev \
    libfreeimage-dev \
    libgoogle-glog-dev \
    libgflags-dev \
    libglew-dev \
    qtbase5-dev \
    libqt5opengl5-dev \
    libcgal-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libboost-filesystem-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-filesystem-dev set to manually installed.
# libboost-program-options-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-program-options-dev set to manually installed.
# libboost-system-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-system-dev set to manually installed.
# libboost-graph-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-graph-dev set to manually installed.
# libboost-test-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-test-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# git is already the newest version (1:2.17.1-1ubuntu0.9).
# qtbase5-dev is already the newest version (5.9.5+dfsg-0ubuntu2.6).
# ...

# %%
# !sudo apt-get install libcgal-qt5-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libcgal-qt5-13 libqt5svg5
# The following NEW packages will be installed:
#   libcgal-qt5-13 libcgal-qt5-dev libqt5svg5
# 0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 345 kB of archives.
# After this operation, 1,364 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5svg5 amd64 5.9.5-0ubuntu1.1 [129 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcgal-qt5-13 amd64 4.11-2build1 [93.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcgal-qt5-dev amd64 4.11-2build1 [122 kB]
# Fetched 345 kB in 1s (322 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/nerf_project'

# %%
# !sudo apt-get install libatlas-base-dev libsuitesparse-dev
# !git clone https://ceres-solver.googlesource.com/ceres-solver
# %cd ceres-solver
# !git checkout $(git describe --tags) # Checkout the latest release
# %mkdir build
# %cd build
# !cmake .. -DBUILD_TESTING=OFF -DBUILD_EXAMPLES=OFF
# !make
# !sudo make install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsuitesparse-dev is already the newest version (1:5.1.2-2).
# libatlas-base-dev is already the newest version (3.10.3-5).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /content/drive/MyDrive/nerf_project/ceres-solver
# /content/drive/MyDrive/nerf_project/ceres-solver/build
# -- Detected Ceres version: 2.1.0 from /content/drive/MyDrive/nerf_project/ceres-solver/include/ceres/version.h
# -- Detected available Ceres threading models: [CXX_THREADS, OPENMP, NO_THREADS]
# -- Found Eigen version 3.3.4: /usr/lib/cmake/eigen3
# -- Enabling use of Eigen as a sparse linear algebra library.
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/nerf_project/ceres-solver/build'

# %%
# %cd /content/drive/MyDrive/nerf_project
# Out:
# /content/drive/MyDrive/nerf_project

# %%
# !git clone https://github.com/colmap/colmap
# %cd colmap
# !git checkout dev
# %mkdir build
# %cd build
# !cmake ..
# !make
# !sudo make install
# !CC=/usr/bin/gcc-6 CXX=/usr/bin/g++-6 cmake ..
# Out:
# /content/drive/MyDrive/nerf_project/colmap
# /content/drive/MyDrive/nerf_project/colmap/build
# -- Found required Ceres dependency: Eigen version 3.3.4 in /usr/lib/cmake/eigen3
# -- Found required Ceres dependency: glog
# -- Found required Ceres dependency: gflags
# -- Found Ceres version: 2.1.0 installed in: /usr/local with components: [EigenSparse, SparseLinearAlgebraLibrary, LAPACK, SuiteSparse, CXSparse, SchurSpecializations, Multithreading]
# -- Boost version: 1.65.1
# -- Found the following Boost libraries:
# --   program_options
# --   filesystem
# --   graph
# --   system
# --   unit_test_framework
# -- Found Eigen
# --   Includes : /usr/include/eigen3
# -- Found FreeImage
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libfreeimage.so
# -- Found Glog
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libglog.so
# -- Found Glew
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libGLEW.so
# ...

# %%
# %cd /content/drive/MyDrive/nerf_project/svox2
# Out:
# /content/drive/MyDrive/nerf_project/svox2

# %%
# !pip install .
# Out:
# Processing /content/drive/MyDrive/nerf_project/svox2
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for svox2: filename=svox2-0.0.1.dev0+sphtexcub.lincolor.fast-cp37-cp37m-linux_x86_64.whl size=3140470 sha256=1719ed2d1ed9ee7e51da2a564054b6dce640076e409d5098418b0f0f655d9cc7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ezy9e1r4/wheels/05/18/ae/37dccd98038e53d3baf0a355afc3f2ff6f042bf96dfb2ae7d0
# Successfully built svox2
# ...

# %%
# %cd /content/drive/MyDrive/nerf_project/svox2/opt/scripts
# Out:
# /content/drive/MyDrive/nerf_project/svox2/opt/scripts

# %%
rm_bg_rotate = '/content/drive/MyDrive/nerf_project/input_data/image5_owl_rm_bg_rotate'
result_path = '/content/drive/MyDrive/nerf_project/result/owl'

# %%
# /content/drive/MyDrive/nerf_project/input_data/image2_rm_bg_rotate

# !bash proc_colmap.sh {rm_bg_rotate}
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
#   => Merged observations: 0
#   => Completed observations: 1
#   => Filtered observations: 0
#   => Changed observations: 0.000372
#
# ...
# Registering image #10 (30)
# ...
#
#   => Image sees 299 / 463 points
#
# Pose refinement report
# ----------------------
#     Residuals : 574
#    Parameters : 6
#    Iterations : 8
#          Time : 0.00469804 [s]
#  Initial cost : 0.606674 [px]
#    Final cost : 0.51337 [px]
#   Termination : Convergence
#
#   => Continued observations: 277
#   => Added observations: 125
#
# Bundle adjustment report
# ------------------------
#     Residuals : 4858
#    Parameters : 881
#    Iterations : 8
#          Time : 0.0382891 [s]
#  Initial cost : 0.486832 [px]
#    Final cost : 0.469786 [px]
#   Termination : Convergence
#
#   => Merged observations: 52
#   => Completed observations: 3
#   => Filtered observations: 37
#   => Changed observations: 0.034252
#
# Bundle adjustment report
# ------------------------
# ...

# %%
# %cd /content/drive/MyDrive/nerf_project/svox2/opt
# Out:
# /content/drive/MyDrive/nerf_project/svox2/opt

# %%
# /content/drive/MyDrive/nerf_project/input_data/image2_rm_bg_rotate
# brown_man

# 왜인진 모르겠지만 454 - 456 주석 처리하면 됨.

# !python opt.py {rm_bg_rotate} -t {result_path}
# Out:
# Defaulting to extended NSVF dataset
# LOAD NSVF DATA /content/drive/MyDrive/nerf_project/input_data/image5_owl_rm_bg_rotate split train
# 100% 95/95 [00:01<00:00, 89.75it/s]
# NORMALIZE BY? camera
# scene_scale 0.04164103714482688
#  intrinsics (loaded reso) Intrin(fx=717.2724193362336, fy=717.2724193362336, cx=216.0, cy=384.0)
#  Generating rays, scaling factor 1
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !pip install lpips
# Out:
# ...
#      |████████████████████████████████| 53 kB 2.1 MB/s
# ...

# %%
# %cd /content/drive/MyDrive/nerf_project/svox2/opt
# Out:
# /content/drive/MyDrive/nerf_project/svox2/opt

# %%
ckpt_path = '/content/drive/MyDrive/nerf_project/result/owl/ckpt.npz'

# %%
# /ckpt/brown_man/ckpt.npz
# /content/drive/MyDrive/nerf_project/input_data/image2_rm_bg_rotate
# 188 - 193 주석 처리

# !python render_imgs.py {ckpt_path} {rm_bg_rotate} --no_imsave
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.7/dist-packages/lpips/weights/v0.1/vgg.pth
# Defaulting to extended NSVF dataset
# LOAD NSVF DATA /content/drive/MyDrive/nerf_project/input_data/image5_owl_rm_bg_rotate split test
# 100% 7/7 [00:00<00:00, 52.77it/s]
# NORMALIZE BY? camera
# scene_scale 0.04164103714482688
#  intrinsics (loaded reso) Intrin(fx=717.2724193362336, fy=717.2724193362336, cx=216.0, cy=384.0)
# Writing to /content/drive/MyDrive/nerf_project/result/owl/test_renders
#   0% 0/7 [00:00<?, ?it/s]0 PSNR 39.760555356773786 SSIM 0.995001494884491 LPIPS 0.023935917764902115
#  14% 1/7 [00:00<00:01,  5.65it/s]1 PSNR 36.34029188185903 SSIM 0.990053653717041 LPIPS 0.03583735227584839
#  29% 2/7 [00:00<00:00,  6.07it/s]2 PSNR 33.33066189498163 SSIM 0.9837256073951721 LPIPS 0.04799406975507736
#  43% 3/7 [00:00<00:00,  6.52it/s]3 PSNR 17.823286704327682 SSIM 0.9573721885681152 LPIPS 0.17514321208000183
# ...

# %%
# !python render_imgs_circle.py {ckpt_path} {rm_bg_rotate}
# Out:
# Defaulting to extended NSVF dataset
# LOAD NSVF DATA /content/drive/MyDrive/nerf_project/input_data/image5_owl_rm_bg_rotate split test
# 100% 7/7 [00:00<00:00, 83.40it/s]
# NORMALIZE BY? camera
# scene_scale 0.04164103714482688
#  intrinsics (loaded reso) Intrin(fx=717.2724193362336, fy=717.2724193362336, cx=216.0, cy=384.0)
#   Auto vec_up [-0.03137467 -0.99878141  0.03809627]
# tensor([0., 0., 0.]) tensor([1., 1., 1.])
# Writing to /content/drive/MyDrive/nerf_project/result/owl/circle_renders.mp4
# 100% 1200/1200 [01:36<00:00, 12.43it/s]
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=8, resizing from (773, 432) to (776, 432) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.
